# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("p1.jpg")
plt.imshow(img)
# plt.axis('off') 
plt.show()

# %%
# print(img)
img.shape
# Out:
# (4177, 2350, 3)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

img_rgb.shape
# Out:
# (4177, 2350, 3)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
resized_img_rgb = cv2.resize(img_rgb, (200,500))
plt.imshow(resized_img_rgb)

# %%
crop = img_rgb[1500:3500, 100:2000]
plt.imshow(crop)

# %%
rotated_img = cv2.rotate(img_rgb, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(rotated_img)

# %%
# contrast change
new_img = cv2.convertScaleAbs(img_rgb, alpha=2.5, beta=15)
plt.imshow(new_img)

# %%
green = np.uint8([[[0,255,0 ]]])
img_green = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img_green)

# %%
image = cv2.putText(img, 'OpenCV', org, font, 
                   fontScale, color, thickness, cv2.LINE_AA)

# %%
(B, G, R) = cv2.split(img)
zeros = np.zeros_like(R)

red_image = cv2.merge([R,zeros, zeros])
blue_image = cv2.merge([zeros, zeros,B])
green_image = cv2.merge([zeros,G, zeros])

plt.imshow(red_image)

# %%
plt.imshow(blue_image)

# %%
plt.imshow(green_image)

# %%
new_image = cv2.putText(
  img_rgb,
  text = "Hello World",
  org = (500,500),
  fontFace = cv2.FONT_HERSHEY_DUPLEX,
  fontScale = 10,
  color = (255, 0, 0),
  thickness = 3
)

plt.imshow(new_image)

# %%
img2 = cv2.imread("p2.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img2_resz = cv2.resize(img2, (500,500))
plt.imshow(img2_resz)

# %%
img3 = cv2.imread("p3.jpg")
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img3_resz = cv2.resize(img3, (500,500))
plt.imshow(img3_resz)

# %%
dst = cv2.addWeighted(img2_resz, 0.5, img3_resz, 0.5, 0)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
